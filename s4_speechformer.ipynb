# %% [markdown]
# <a href="https://colab.research.google.com/github/Barelella/S4SpeechFormer/blob/Ella_test_branch/s4_speechforner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_speechformer_dir = './drive/Othercomputers/My Laptop/S4SpeechFormer'

# %%
os.chdir(path_to_speechformer_dir)

# %%
os.listdir('./')
# Out:
# ['README.md',
#  'figures',
#  'model',
#  'config',
#  'module',
#  'extract_feature',
#  'train_model.py',
#  'utils',
#  '.git',
#  '.gitignore',
#  'requirements.txt',
#  'metadata',
#  's4_speechformer.ipynb']

# %%
# Out:
# ...
#   Using cached fairseq-0.10.2.tar.gz (938 kB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
